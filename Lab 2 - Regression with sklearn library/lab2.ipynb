# %% [markdown]
# # Exercise 1: Approximate the function  𝑓(𝑥)=1/+𝑥^2 in the interval  [-5,5]
# using the sklearn routines PolynomialFeatures without regularization and with regularization Lasso, Ridge, and ElasticNet.

# %% [markdown]
# Import the Library

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %% [markdown]
# Define the function to approximate

# %%
def f(x):
    return 1/(1 + x**2)

# %% [markdown]
# Generate random data in the interval[-5,5]

# %%
np.random.seed(0)
x_train = np.random.uniform(-5, 5, size=(100,))
y_train = f(x_train) + np.random.normal(scale=0.1, size=x_train.shape)
degrees = [3, 7, 15, 21]

# %% [markdown]
# Fit the data using PolynomialFeatures without regularization

# %%
plt.figure(figsize=(16, 8))
for i, degree in enumerate(degrees):
    ax = plt.subplot(2, len(degrees), i + 1)
    plt.setp(ax, xticks=(), yticks=())

    # Create a polynomial feature transformer and fit the data
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = LinearRegression()
    pipeline = make_pipeline(polynomial_features, linear_regression)
    pipeline.fit(x_train[:, np.newaxis], y_train)

    # Evaluate the model and plot the results
    x_plot = np.linspace(-5, 5, 100)
    y_plot = pipeline.predict(x_plot[:, np.newaxis])
    plt.plot(x_train, y_train, 'b.', markersize=10)
    plt.plot(x_plot, y_plot, 'r-', label='Degree %d' % degree)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.ylim((-0.1, 1.1))
    plt.legend(loc='best')

# %% [markdown]
# Fit the data using Lasso regularization

# %%
for i, degree in enumerate(degrees):
    ax = plt.subplot(2, len(degrees), i + 1 + len(degrees))
    plt.setp(ax, xticks=(), yticks=())

    # Create a polynomial feature transformer and fit the data
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = Lasso(alpha=0.01)
    pipeline = make_pipeline(polynomial_features, linear_regression)
    pipeline.fit(x_train[:, np.newaxis], y_train)

    # Evaluate the model and plot the results
    x_plot = np.linspace(-5, 5, 100)
    y_plot = pipeline.predict(x_plot[:, np.newaxis])
    plt.plot(x_train, y_train, 'b.', markersize=10)
    plt.plot(x_plot, y_plot, 'r-', label='Degree %d' % degree)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.ylim((-0.1, 1.1))
    plt.legend(loc='best')
# Out:
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.357e-01, tolerance: 8.981e-04
#   model = cd_fast.enet_coordinate_descent(
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.510e-01, tolerance: 8.981e-04
#   model = cd_fast.enet_coordinate_descent(
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.494e-01, tolerance: 8.981e-04
# ...

# %% [markdown]
# Fit the data using Ridge regularization

# %%
for i, degree in enumerate(degrees):
    ax = plt.subplot(2, len(degrees), i + 1 + len(degrees))
    plt.setp(ax, xticks=(), yticks=())

    # Create a polynomial feature transformer and fit the data
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = Ridge(alpha=0.01)
    pipeline = make_pipeline(polynomial_features, linear_regression)
    pipeline.fit(x_train[:, np.newaxis], y_train)

    # Evaluate the model and plot the results
    x_plot = np.linspace(-5, 5, 100)
    y_plot = pipeline.predict(x_plot[:, np.newaxis])
    plt.plot(x_train, y_train, 'b.', markersize=10)
    plt.plot(x_plot, y_plot, 'r-', label='Degree %d' % degree)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.ylim((-0.1, 1.1))
    plt.legend(loc='best')
# Out:
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.70337e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.538e-31): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %% [markdown]
# Fit the data using ElasticNet regularization

# %%
for i, degree in enumerate(degrees):
    ax = plt.subplot(2, len(degrees), i + 1 + len(degrees))
    plt.setp(ax, xticks=(), yticks=())

    # Create a polynomial feature transformer and fit the data
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = ElasticNet(alpha=0.01, l1_ratio=0.5)
    pipeline = make_pipeline(polynomial_features, linear_regression)
    pipeline.fit(x_train[:, np.newaxis], y_train)

    # Evaluate the model and plot the results
    x_plot = np.linspace(-5, 5, 100)
    y_plot = pipeline.predict(x_plot[:, np.newaxis])
    plt.plot(x_train, y_train, 'b.', markersize=10)
    plt.plot(x_plot, y_plot, 'r-', label='Degree %d' % degree)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.ylim((-0.1, 1.1))
    plt.legend(loc='best')
# Out:
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.199e-01, tolerance: 8.981e-04
#   model = cd_fast.enet_coordinate_descent(
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.578e-01, tolerance: 8.981e-04
#   model = cd_fast.enet_coordinate_descent(
# d:\app\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.572e-01, tolerance: 8.981e-04
# ...

# %% [markdown]
# # Exercise 2: Identify a regression noise dataset from UCI repository https://archive.ics.uci.edu/ml/datasets.php and apply on it Bayesian Ridge Regression, Gaussian Process Regression, and Ridge Regression with Cross-Validation.

# %% [markdown]
# I choice the  "Energy efficiency" dataset

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import BayesianRidge, RidgeCV
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load the dataset

# %%
data = pd.read_excel('data/ENB2012_data.xlsx')

# %% [markdown]
# Split the data into input features (X) and output variable (y)

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %% [markdown]
# Split the data into training and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Fit to the Bayesian Ridge Regrassion model

# %%
bay = BayesianRidge(compute_score=True)
bay.fit(X_train, y_train)
bay.score(X_test, y_test)
# Out:
# 0.9570955396979418

# %% [markdown]
# Fit to the Gaussian Process Regression model

# %%
kernel = RBF()
gau = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, normalize_y=True)
gau.fit(X_train, y_train)
gau.score(X_test, y_test)
# Out:
# 0.9336853104876983

# %% [markdown]
# Fit Ridge Regression with Cross-Validasion model

# %%
cvm = RidgeCV(alphas=[0.1, 1.0, 10.0], cv=5)
cvm.fit(X_train, y_train)
cvm.score(X_test, y_test)
# Out:
# 0.9576315917755188

# %% [markdown]
# Print the score for each model

# %%
print('BayesianRidge: ', bay.score(X_test, y_test))
print('GaussianProcessRegressor: ', gau.score(X_test, y_test))
print('RidgeCV: ', cvm.score(X_test, y_test))
# Out:
# BayesianRidge:  0.9570955396979418
# GaussianProcessRegressor:  0.9336853104876983
# RidgeCV:  0.9576315917755188

# %% [markdown]
# # Exercise 3: Compare the above kernel regression methods on this synthetic dataset.

# %% [markdown]
# Generate the data.

# %%
from sklearn.datasets import make_regression
import numpy as np
import  matplotlib.pyplot as plt

# Generate synthetic dataset with 1000 samples and 10 features
X, y = make_regression(n_samples=1000, n_features=10, noise=0.1)

# Add Gaussian noise to target variable
y += np.random.normal(0, 1, size=y.shape)

# %% [markdown]
# Split the data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Fit to the Bayesian Ridge Regrassion model.

# %%
bay = BayesianRidge(compute_score=True)
bay.fit(X_train, y_train)
bay.score(X_test, y_test)
# Out:
# 0.9999726831972343

# %% [markdown]
# Fit to the Gaussian Process Regression model

# %%
kernel = RBF()
gau = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, normalize_y=True)
gau.fit(X_train, y_train)
gau.score(X_test, y_test)
# Out:
# 0.9995287360397455

# %% [markdown]
# Fit Ridge Regression with Cross-Validasion model

# %%
cvm = RidgeCV(alphas=[0.1, 1.0, 10.0], cv=5)
cvm.fit(X_train, y_train)
cvm.score(X_test, y_test)
# Out:
# 0.9999725662496026

# %% [markdown]
# Print the scor for each model

# %%
print('BayesianRidge: ', bay.score(X_test, y_test))
print('GaussianProcessRegressor: ', gau.score(X_test, y_test))
print('RidgeCV: ', cvm.score(X_test, y_test))
# Out:
# BayesianRidge:  0.9999726831972343
# GaussianProcessRegressor:  0.9995287360397455
# RidgeCV:  0.9999725662496026

# %% [markdown]
# # Exercise 5: This project will identify the factors among a student’s socioeconomic status, study attitude, school that impact the students’ school performance most, especially to check if alcohol use will affect students’ grades, with support of real-world data. In addition, it compares the machine learning techniques KNNs, SVR, Linear Regression and Trees for regression problems.

# %% [markdown]
# Import the librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Load the data

# %%
data = pd.read_csv("data/student-mat.csv", delimiter=";")
# data = data[(data["school"] == "GP")]
X = data.iloc[:, :-3]
y = data.iloc[:, -3]

# %% [markdown]
# Convert categorical variables to numerical using LabelEncoder

# %%
categorical_cols = ["school", "sex", "address", "famsize", "Pstatus", "Mjob", "Fjob", "reason", "guardian", "schoolsup", "famsup", "paid", "activities", "nursery", "higher", "internet", "romantic"]
le = LabelEncoder()
for col in categorical_cols:
    X[col] = le.fit_transform(X[col])

# %% [markdown]
# One-hot encode nominal categorical variables

# %%
X = pd.get_dummies(X, columns=["Medu", "Fedu", "traveltime", "studytime", "failures", "famrel", "freetime", "goout", "Dalc", "Walc", "health"])

# %% [markdown]
# Split data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Standardize features

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# KNN regression

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)
knn_mse = mean_squared_error(y_test, knn_pred)

# %% [markdown]
# SVR

# %%
svr = SVR(kernel='linear')
svr.fit(X_train, y_train)
svr_pred = svr.predict(X_test)
svr_mse = mean_squared_error(y_test, svr_pred)

# %% [markdown]
# Linear Regression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
lin_reg_pred = lin_reg.predict(X_test)
lin_reg_mse = mean_squared_error(y_test, lin_reg_pred)

# %% [markdown]
# Ridge Regression with Cross-Validation

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
ridge_pred = ridge.predict(X_test)
ridge_mse = mean_squared_error(y_test, ridge_pred)

# %% [markdown]
# Decision Tree Regression

# %%
tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(X_train, y_train)
tree_reg_pred = tree_reg.predict(X_test)
tree_reg_mse = mean_squared_error(y_test, tree_reg_pred)

# %% [markdown]
# Print all

# %%
print('KNN: ', knn_mse)
print('SVR: ', svr_mse)
print('Linear Regression: ', lin_reg_mse)
print('Ridge: ', ridge_mse)
print('Decision Tree: ', tree_reg_mse)
# Out:
# KNN:  12.85974683544304
# SVR:  10.891013665605838
# Linear Regression:  4.4012821199463957e+27
# Ridge:  10.174288157192818
# Decision Tree:  19.734177215189874

# %% [markdown]
# # Exercise7: Choose a dataset from UCI repository and apply the above analysis.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR

# %% [markdown]
# Load the dataset

# %%
X, y = make_regression(n_samples=1000, n_features=10, noise=0.1)
y += np.random.normal(0, 1, size=y.shape)

scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.reshape(-1, 1))

# %% [markdown]
# Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Train and Eavaluate

# %% [markdown]
# Grandient Boosting Machines

# %%
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=1, random_state=0, loss='ls')
gbr.fit(X_train, y_train)
gbr_pred = gbr.predict(X_test)
gbr_mse = mean_squared_error(y_test, gbr_pred)
# Out:
# d:\app\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# d:\app\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(

# %% [markdown]
# Ridge Regression

# %%
ridge = Ridge(alpha=0.4)
ridge.fit(X_train, y_train)
ridge_pred = ridge.predict(X_test)
ridge_mse = mean_squared_error(y_test, ridge_pred)

# %% [markdown]
# SVR

# %%
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr.fit(X_train, y_train)
svr_pred = svr.predict(X_test)
svr_mse = mean_squared_error(y_test, svr_pred)
# Out:
# d:\app\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# Lasso Regression

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(X_train, y_train)
lasso_pred = lasso.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_pred)

# %% [markdown]
# Random Forest

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=2, random_state=0)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
rf_mse = mean_squared_error(y_test, rf_pred)
# Out:
# C:\Users\ptolo\AppData\Local\Temp\ipykernel_13352\1593567006.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)

# %% [markdown]
# Decision Tree

# %%
dt = DecisionTreeRegressor(max_depth=10)
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)
dt_mse = mean_squared_error(y_test, dt_pred)

# %% [markdown]
# KNN

# %%
knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)
knn_mse = mean_squared_error(y_test, knn_pred)

# %% [markdown]
# Print the result

# %%
print('GradientBoostingRegressor: ', gbr_mse, gbr.score(X_test, y_test))
print('Ridge: ', ridge_mse, ridge.score(X_test, y_test))
print('SVR: ', svr_mse, svr.score(X_test, y_test))
print('Lasso: ', lasso_mse, lasso.score(X_test, y_test))
print('RandomForestRegressor: ', rf_mse, rf.score(X_test, y_test))
print('DecisionTreeRegressor: ', dt_mse, dt.score(X_test, y_test))
print('KNeighborsRegressor: ', knn_mse, knn.score(X_test, y_test))
# Out:
# GradientBoostingRegressor:  0.26324315060573666 0.7638805949753451
# Ridge:  3.0334807485755227e-05 0.9999727907955873
# SVR:  0.0538097429015654 0.9517346436205039
# Lasso:  0.10202162076050295 0.9084903658910396
# RandomForestRegressor:  0.7376578219240105 0.33834811799018005
# DecisionTreeRegressor:  0.4518646083616041 0.5946940984692974
# KNeighborsRegressor:  0.24151780654678176 0.7833674279711988
